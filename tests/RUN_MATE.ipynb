# %%
import os
import sys
sys.path.append(r'C:\Users\Zimeng\Documents\Code\MATE\src\mate-manager')
import numpy as np
import scipy.ndimage as ndi
import matplotlib.pyplot as plt
from start import main_scheduler
from feedback_txt import send_xyz_to_scope
from masking import analyze_image

# %%
send_xyz_to_scope(z_pos=1,y_pos=2,x_pos=3)
# Out:
# True

# %%
with open(r'coords.txt','r') as infile: #put where the python script spits out coordinates
    #for line in infile.readlines():
    newest_line = infile.readlines()[-1]

x_pos = int(newest_line.split('X:')[1].split(', ')[0])
y_pos = int(newest_line.split('Y:')[1].split(', ')[0])
z_pos = int(newest_line.split('Z:')[1])

print(x_pos)
print(y_pos)
print(z_pos)
# Out:
# 3
# 2
# 1

# %%
dirpath = r'C:\Users\Zimeng\Documents\Code\MATE_test_data'

main_scheduler(target_dir=dirpath,interval=10,fileStart='516x180',fileEnd='.czi',img_params=None,scope_params=None,verbose=False)
# Out:
# MONITORING IN PROGRESS...
# Press <Esc> to terminate.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 dirpath = r'C:\Users\Zimeng\Documents\Code\MATE_test_data'
# ----> 3 main_scheduler(target_dir=dirpath,interval=10,fileStart='516x180',fileEnd='.czi',img_params=None,scope_params=None,verbose=False)
#
# File ~\Documents\Code\MATE\src\mate-manager\start.py:305, in main_scheduler(target_dir, interval, fileStart, fileEnd, img_params, scope_params, verbose)
#     303     # If nothing is found, wait for the intervall to pass
#     304     check_counter += 1
# --> 305     sleep(interval)
#     308 #..........................................................................
#     309
#     310 # FINISH AND REPORT
#     311
#     312 # Report
#     313 print("\n\nMONITORING TERMINATED!")
#
# KeyboardInterrupt:

# %%
z_pos,y_pos,x_pos = analyze_image(filename,channel=channel,show=True,verbose=True)
print("Returned coords were:")
print("  z:", z_pos)
print("  y:", y_pos)
print("  x:", x_pos)
